# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
excel_file='D:\\MyDataAnalisisAllData\\AnilPython\\movies.xls'
movies=pd.read_excel(excel_file)

# %%
movies
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# 5                                  The Broadway Melody   1929
# 6                                        Hell's Angels   1930
# 7                                   A Farewell to Arms   1932
# 8                                          42nd Street   1933
# 9                                   She Done Him Wrong   1933
# 10                               It Happened One Night   1934
# 11                                             Top Hat   1935
# 12                                        Modern Times   1936
# 13                     The Charge of the Light Brigade   1936
# ...

# %%
movies.head(10)
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
# 5                               The Broadway Melody   1929
# 6                                     Hell's Angels   1930
# 7                                A Farewell to Arms   1932
# 8                                       42nd Street   1933
# 9                                She Done Him Wrong   1933
#
#                                  Genres Language  Country Content Rating  \
# 0                     Drama|History|War      NaN      USA      Not Rated
# 1                           Crime|Drama      NaN      USA            NaN
# 2                     Drama|Romance|War      NaN      USA      Not Rated
# ...

# %%
movies.tail()
# Out:
#                                Title  Year                        Genres  \
# 1333               Twin Falls Idaho   1999                         Drama
# 1334  Universal Soldier: The Return   1999                 Action|Sci-Fi
# 1335                  Varsity Blues   1999    Comedy|Drama|Romance|Sport
# 1336                 Wild Wild West   1999  Action|Comedy|Sci-Fi|Western
# 1337                 Wing Commander   1999       Action|Adventure|Sci-Fi
#
#      Language Country Content Rating  Duration  Aspect Ratio       Budget  \
# 1333  English     USA              R       111          1.85     500000.0
# 1334  English     USA              R        83          1.85   24000000.0
# 1335  English     USA              R       106          1.85   16000000.0
# 1336  English     USA          PG-13       106          1.85  170000000.0
# 1337  English     USA          PG-13       100          2.35   30000000.0
#
#       Gross Earnings     ...     Facebook Likes - Actor 1  \
# ...

# %%
movies.shape
# Out:
# (1338, 25)

# %%
movies.isnull().sum()
# Out:
# Title                            0
# Year                             0
# Genres                           0
# Language                         4
# Country                          0
# Content Rating                  22
# Duration                         0
# Aspect Ratio                    30
# Budget                          57
# Gross Earnings                 252
# Director                         0
# Actor 1                          0
# Actor 2                          0
# Actor 3                          2
# Facebook Likes - Director        0
# Facebook Likes - Actor 1         0
# Facebook Likes - Actor 2         0
# Facebook Likes - Actor 3         2
# Facebook Likes - cast Total      0
# Facebook likes - Movie           0
# Facenumber in posters            0
# User Votes                       0
# Reviews by Users                 0
# Reviews by Crtiics               3
# IMDB Score                       0
# dtype: int64

# %%
movies['Country'].head()
# Out:
# 0        USA
# 1        USA
# 2        USA
# 3    Germany
# 4    Germany
# Name: Country, dtype: object

# %%
m=pd.read_excel(excel_file,sheetname=0,col_index=0)
m1=pd.read_excel(excel_file,sheetname=1,col_index=0)
m2=pd.read_excel(excel_file,sheetname=2,col_index=0)
movies=pd.concat([m,m1,m2])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
movies.shape
# Out:
# (5042, 25)

# %%
xlsx = pd.ExcelFile(excel_file)
movies_sheets = []
for sheet in xlsx.sheet_names:
    movies_sheets.append(xlsx.parse(sheet))
movies = pd.concat(movies_sheets)

# %%
movies.shape
# Out:
# (5042, 25)

# %%
sorted_by_gross = movies.sort_values(['Gross Earnings'], ascending=False)
sorted_by_gross['Gross Earnings'].head()
# Out:
# 1867    760505847.0
# 1027    658672302.0
# 1263    652177271.0
# 610     623279547.0
# 611     623279547.0
# Name: Gross Earnings, dtype: float64

# %%
sorted_by_gross['Gross Earnings'].plot(kind='bar')

# %%
movies.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  4935.000000  5028.000000   4714.000000  4.551000e+03    4.159000e+03
# mean   2002.470517   107.201074      2.220403  3.975262e+07    4.846841e+07
# std      12.474599    25.197441      1.385113  2.061149e+08    6.845299e+07
# min    1916.000000     7.000000      1.180000  2.180000e+02    1.620000e+02
# 25%    1999.000000    93.000000      1.850000  6.000000e+06    5.340988e+06
# 50%    2005.000000   103.000000      2.350000  2.000000e+07    2.551750e+07
# 75%    2011.000000   118.000000      2.350000  4.500000e+07    6.230944e+07
# max    2016.000000   511.000000     16.000000  1.221550e+10    7.605058e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                4938.000000               5035.000000
# mean                  686.621709               6561.323932
# std                  2813.602405              15021.977635
# ...

# %%
sorted_by_gross[['Gross Earnings','Duration','Aspect Ratio']].mode()
# Out:
#    Gross Earnings  Duration  Aspect Ratio
# 0       3000000.0      90.0          2.35
# 1       5773519.0       NaN           NaN
# 2       8000000.0       NaN           NaN
# 3      34964818.0       NaN           NaN
# 4      47000000.0       NaN           NaN
# 5     144512310.0       NaN           NaN
# 6     177343675.0       NaN           NaN
# 7     218051260.0       NaN           NaN

# %%
movies_skip_rows = pd.read_excel(excel_file, header=None, skiprows=4)
movies_skip_rows.head(5)
# Out:
#                      0     1                    2        3        4   \
# 0           Metropolis   1927         Drama|Sci-Fi   German  Germany
# 1        Pandora's Box   1929  Crime|Drama|Romance   German  Germany
# 2  The Broadway Melody   1929      Musical|Romance  English      USA
# 3        Hell's Angels   1930            Drama|War  English      USA
# 4   A Farewell to Arms   1932    Drama|Romance|War  English      USA
#
#           5    6     7          8          9  ...    15   16    17    18  \
# 0  Not Rated  145  1.33  6000000.0    26435.0 ...   136   23  18.0   203
# 1  Not Rated  110  1.33        NaN     9950.0 ...   426   20   3.0   455
# 2     Passed  100  1.37   379000.0  2808000.0 ...    77   28   4.0   109
# 3     Passed   96  1.20  3950000.0        NaN ...   431   12   4.0   457
# 4    Unrated   79  1.37   800000.0        NaN ...   998  164  99.0  1284
#
#       19  20      21   22     23   24
# 0  12000   1  111841  413  260.0  8.3
# ...

# %%
movies_subset_columns = pd.read_excel(excel_file, parse_cols=0)
movies_subset_columns.head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   """Entry point for launching an IPython kernel.
#                                                Title
# 0  Intolerance: Love's Struggle Throughout the Ages
# 1                    Over the Hill to the Poorhouse
# 2                                    The Big Parade
# 3                                        Metropolis
# 4                                     Pandora's Box

# %%
movies["Net Earnings"] = movies["Gross Earnings"] - movies["Budget"]

# %%
movies["Net Earnings"].head()
# Out:
# 0          NaN
# 1    2900000.0
# 2          NaN
# 3   -5973565.0
# 4          NaN
# Name: Net Earnings, dtype: float64

# %%
movies_subset = movies[['Year', 'Gross Earnings']]
movies_subset.head()
# Out:
#      Year  Gross Earnings
# 0  1916.0             NaN
# 1  1920.0       3000000.0
# 2  1925.0             NaN
# 3  1927.0         26435.0
# 4  1929.0          9950.0

# %%
earnings_by_year = movies_subset.pivot_table(index=['Year'])
earnings_by_year.head()
# Out:
#         Gross Earnings
# Year
# 1916.0             NaN
# 1920.0       3000000.0
# 1925.0             NaN
# 1927.0         26435.0
# 1929.0       1408975.0

# %%
earnings_by_year.plot()
plt.show()

# %%
movies_subset = movies[['Country', 'Language', 'Gross Earnings']]
movies_subset.head()
# Out:
#    Country Language  Gross Earnings
# 0      USA      NaN             NaN
# 1      USA      NaN       3000000.0
# 2      USA      NaN             NaN
# 3  Germany   German         26435.0
# 4  Germany   German          9950.0

# %%
earnings_by_co_lang = movies_subset.pivot_table(index=['Country', 'Language'])
earnings_by_co_lang.head()
# Out:
#                         Gross Earnings
# Country     Language
# Afghanistan Dari          1.127331e+06
# Argentina   Spanish       7.230936e+06
# Aruba       English       1.007614e+07
# Australia   Aboriginal    6.165429e+06
#             Dzongkha      5.052950e+05

# %%
earnings_by_co_lang.head(20).plot(kind='bar', figsize=(20,8))
plt.show()

# %%
movies.to_excel('a.xls')
